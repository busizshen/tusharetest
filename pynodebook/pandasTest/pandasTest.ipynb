# %%
import pandas as pd
path=r"D:\PycharmProjects\tusharetest\tushareTest\data\todayAll\20180109152157.csv"
# D:\PycharmProjects\tusharetest\tushareTest\data\todayAll
# D:\PycharmProjects\tusharetest\pynodebook\pandasTest
data = pd.read_csv(path)
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>code</th>
#       <th>name</th>
#       <th>changepercent</th>
#       <th>trade</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>settlement</th>
#       <th>volume</th>
#       <th>turnoverratio</th>
#       <th>amount</th>
#       <th>per</th>
#       <th>pb</th>
#       <th>mktcap</th>
#       <th>nmc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>603999</td>
#       <td>读者传媒</td>
#       <td>0.516</td>
#       <td>7.79</td>
#       <td>7.76</td>
#       <td>7.82</td>
#       <td>7.72</td>
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3478 entries, 0 to 3477
# Data columns (total 16 columns):
# Unnamed: 0       3478 non-null int64
# code             3478 non-null int64
# name             3478 non-null object
# changepercent    3478 non-null float64
# trade            3478 non-null float64
# open             3478 non-null float64
# high             3478 non-null float64
# low              3478 non-null float64
# settlement       3478 non-null float64
# volume           3478 non-null float64
# turnoverratio    3478 non-null float64
# amount           3478 non-null float64
# per              3478 non-null float64
# pb               3478 non-null float64
# mktcap           3478 non-null float64
# nmc              3478 non-null float64
# dtypes: float64(13), int64(2), object(1)
# memory usage: 434.8+ KB

# %%
data.code.head(10)
# Out:
# 0    603999
# 1    603998
# 2    603997
# 3    603996
# 4    603993
# 5    603991
# 6    603990
# 7    603989
# 8    603988
# 9    603987
# Name: code, dtype: int64

# %%
data1=data.sort_values(by=['code'],ascending=[False])
data1.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>code</th>
#       <th>name</th>
#       <th>changepercent</th>
#       <th>trade</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>settlement</th>
#       <th>volume</th>
#       <th>turnoverratio</th>
#       <th>amount</th>
#       <th>per</th>
#       <th>pb</th>
#       <th>mktcap</th>
#       <th>nmc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3411</th>
#       <td>3411</td>
#       <td>900951</td>
#       <td>*ST大化B</td>
#       <td>0.000</td>
#       <td>0.832</td>
#       <td>0.828</td>
#       <td>0.847</td>
# ...

# %%
data1 = data1[1:3]
data1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>code</th>
#       <th>name</th>
#       <th>changepercent</th>
#       <th>trade</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>settlement</th>
#       <th>volume</th>
#       <th>turnoverratio</th>
#       <th>amount</th>
#       <th>per</th>
#       <th>pb</th>
#       <th>mktcap</th>
#       <th>nmc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3412</th>
#       <td>3412</td>
#       <td>900930</td>
#       <td>*ST沪普B</td>
#       <td>-1.289</td>
#       <td>0.689</td>
#       <td>0.70</td>
#       <td>0.70</td>
# ...

# %%
data1.iloc[1:,3:]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>changepercent</th>
#       <th>trade</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>settlement</th>
#       <th>volume</th>
#       <th>turnoverratio</th>
#       <th>amount</th>
#       <th>per</th>
#       <th>pb</th>
#       <th>mktcap</th>
#       <th>nmc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3413</th>
#       <td>0.0</td>
#       <td>0.469</td>
#       <td>0.47</td>
#       <td>0.47</td>
#       <td>0.463</td>
#       <td>0.469</td>
#       <td>127200.0</td>
#       <td>0.06564</td>
#       <td>59320.0</td>
#       <td>-2.449</td>
# ...

# %%
# df.loc[df["a"]>5,df.loc["2017-08-15",:]>4]
data1.loc[data1["code"]>5]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>code</th>
#       <th>name</th>
#       <th>changepercent</th>
#       <th>trade</th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>settlement</th>
#       <th>volume</th>
#       <th>turnoverratio</th>
#       <th>amount</th>
#       <th>per</th>
#       <th>pb</th>
#       <th>mktcap</th>
#       <th>nmc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3412</th>
#       <td>3412</td>
#       <td>900930</td>
#       <td>*ST沪普B</td>
#       <td>-1.289</td>
#       <td>0.689</td>
#       <td>0.70</td>
#       <td>0.70</td>
# ...
